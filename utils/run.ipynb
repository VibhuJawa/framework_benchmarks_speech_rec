# %%
# %load extract_features.py
import sys
import os
import numpy as np
import librosa
import itertools
import pickle

def generate(dir, disp=False):
    dir = os.fsencode(dir)
    data = []
    numFiles = len(os.listdir(dir))
    for num, file in enumerate(os.listdir(dir)):
        fname = os.fsencode(file)

        y, sr = librosa.load(dir+fname)
        data.append(librosa.feature.mfcc(y=y, sr=sr))
        if disp: print('processing wavs '+str(round(100*(num+1)/numFiles, 2))+'%', end='\r')

    if disp: print('padding... ', end='')
    maxRows = max([elem.shape[0] for elem in data])
    maxCols = max([elem.shape[1] for elem in data])
    padded = [np.zeros((maxRows, maxCols)) for _ in data]
    for ins, zer in zip(data, padded): zer[:ins.shape[0], :ins.shape[1]] = ins
    if disp: print('done')
   
    return padded




if '__main__' == __name__:
    if len(sys.argv)<3:
        print('provide target dir and source dir')
        exit()
    input_dir = "../data/train_subset/"
    target_dir = "../data/pickles/"
    os.makedirs(target_dir,exist_ok=True)
    for label in os.listdir(input_dir):
        if label == '.DS_Store':
            continue
        curr_dir = input_dir + label +'/'
        print(curr_dir)
        with open(target_dir + '{}_features.pickle'.format(label), 'wb') as fil: pickle.dump(generate(curr_dir, disp=True), fil)
        print('wrote {}_features.pickle'.format(label))
# Out:
# ../data/train_subset/bird/
# padding... done
# wrote bird_features.pickle
# ../data/train_subset/six/
# padding... done
# wrote six_features.pickle
# ../data/train_subset/eight/
# padding... done
# wrote eight_features.pickle
# ../data/train_subset/three/
# padding... done
# wrote three_features.pickle
# ../data/train_subset/off/
# padding... done
# wrote off_features.pickle
# ../data/train_subset/sheila/
# padding... done
# wrote sheila_features.pickle
# ../data/train_subset/no/
# padding... done
# wrote no_features.pickle
# ../data/train_subset/happy/
# padding... done
# wrote happy_features.pickle
# ../data/train_subset/go/
# padding... done
# wrote go_features.pickle
# ../data/train_subset/left/
# padding... done
# wrote left_features.pickle
# ../data/train_subset/on/
# padding... done
# wrote on_features.pickle
# ../data/train_subset/cat/
# padding... done
# wrote cat_features.pickle
# ../data/train_subset/house/
# padding... done
# wrote house_features.pickle
# ../data/train_subset/yes/
# padding... done
# wrote yes_features.pickle
# ../data/train_subset/five/
# padding... done
# wrote five_features.pickle
# ../data/train_subset/up/
# padding... done
# wrote up_features.pickle
# ../data/train_subset/bed/
# padding... done
# wrote bed_features.pickle
# ../data/train_subset/one/
# padding... done
# wrote one_features.pickle
# ../data/train_subset/zero/
# padding... done
# wrote zero_features.pickle
# ../data/train_subset/marvin/
# padding... done
# wrote marvin_features.pickle
# ../data/train_subset/dog/
# padding... done
# wrote dog_features.pickle
# ../data/train_subset/wow/
# padding... done
# wrote wow_features.pickle
# ../data/train_subset/seven/
# padding... done
# wrote seven_features.pickle
# ../data/train_subset/two/
# padding... done
# wrote two_features.pickle
# ../data/train_subset/right/
# padding... done
# wrote right_features.pickle
# ../data/train_subset/tree/
# padding... done
# wrote tree_features.pickle
# ../data/train_subset/down/
# padding... done
# wrote down_features.pickle
# ../data/train_subset/stop/
# padding... done
# wrote stop_features.pickle
# ../data/train_subset/four/
# padding... done
# wrote four_features.pickle
# ../data/train_subset/nine/
# padding... done
# wrote nine_features.pickle
